# %%
import requests
import json
url='https://api.twitter.com/2/openapi.json'
res=requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# data", "meta" ],\n        "properties" : {\n          "data" : {\n            "type" : "array",\n            "description" : "All user-specified stream filtering rules that were created.",\n            "items" : {\n              "$ref" : "#/components/schemas/Rule"\n            }\n          },\n          "meta" : {\n            "$ref" : "#/components/schemas/RulesResponseMetadata"\n          }\n        }\n      },\n      "DeleteRulesRequest" : {\n        "type" : "object",\n        "description" : "A response from deleting user-specified stream filtering rules.",\n        "properties" : {\n          "ids" : {\n            "type" : "array",\n            "description" : "IDs of all deleted user-specified stream filtering rules.",\n            "items" : {\n              "$ref" : "#/components/schemas/RuleId"\n            }\n          },\n          "values" : {\n            "type" : "array",\n            "description" : "Values of all deleted user-specified stream filtering rules.",\n   
# ...

# %%
data = json.loads(res.text)
type(data)
# Out:
# dict

# %%
data
# Out:
# ay',
#       'items': {'$ref': '#/components/schemas/Tweet'},
#       'minItems': 1},
#      'includes': {'$ref': '#/components/schemas/Expansions'},
#      'errors': {'type': 'array',
#       'items': {'$ref': '#/components/schemas/Problem'},
#       'minItems': 1},
#      'meta': {'type': 'object',
#       'properties': {'newest_id': {'type': 'string',
#         'pattern': '^[0-9]{1,19}$',
#         'description': 'Most recent Tweet Id returned by search query'},
#        'oldest_id': {'type': 'string',
#         'pattern': '^[0-9]{1,19}$',
#         'description': 'Oldest Tweet Id returned by search query'},
#        'next_token': {'description': "This value is used to get the next 'page' of results by providing it to the next_token parameter.",
#         'type': 'string'},
#        'result_count': {'description': 'Number of search query results',
#         'type': 'integer',
#         'format': 'int32'}}}}},
#    'StreamingTweet': {'type': 'object',
# ...
